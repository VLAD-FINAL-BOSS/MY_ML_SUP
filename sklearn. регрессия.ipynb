# %%
from sklearn.datasets import load_iris
iris = load_iris(as_frame=True)

# %%
X = iris.data[["sepal length (cm)"]]
y = iris.data["sepal width (cm)"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=0)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-0.03760403])

# %%
reg.intercept_
# Out:
# 3.275667033179375

# %%
import numpy as np
import matplotlib.pyplot as plt

y_reg = reg.predict(x_test)
plt.scatter(x_train, y_train, color='green')
plt.scatter(x_test, y_test, color='red')
plt.plot(x_test, y_reg)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
mse = mean_squared_error(y_test, y_reg)
mae = mean_absolute_error(y_test, y_reg)
mape = mean_absolute_percentage_error(y_test, y_reg)

mse, mae, mape
# Out:
# (0.1849277617643205, 0.33863116685388833, 0.10999902480469738)
